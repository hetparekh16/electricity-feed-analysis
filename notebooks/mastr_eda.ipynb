# %%
from open_mastr import Mastr

# %%
db = Mastr()
# Out:
# Data will be written to the following database: sqlite:////Users/hp8429/.open-MaStR/data/sqlite/open-mastr.db
# If you run into problems, try to delete the database and update the package by running 'pip install --upgrade open-mastr'

# %%
db.download()
# Out:
# Download has started, this can take several minutes.The download bar is only a rough estimate.
# /Users/hp8429/.open-MaStR/data/xml_download/Gesamtdatenexport_20251111.zip: 27234 [23:23, 19.41/s]
# Download is finished. It took 1404 seconds.
# MaStR was successfully downloaded to /Users/hp8429/.open-MaStR/data/xml_download.
#
# Would you like to speed up the bulk download?
# Try our new parallelized processing by setting os.environ['USE_RECOMMENDED_NUMBER_OF_PROCESSES'] = True or configure your own number of processes via os.environ['NUMBER_OF_PROCESSES'] = your_number
#
# Starting bulk download and data cleansing...
# Table 'lokationstypen' is not supported by your open-mastr version and will be skipped.
# Table 'marktakteureundrollen' is not supported by your open-mastr version and will be skipped.
# Table 'marktfunktionen' is not supported by your open-mastr version and will be skipped.
# Processing file 'AnlagenEegBiomasse.xml'...
# Creating table 'biomass_eeg'...
# ...
